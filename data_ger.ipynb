# %%
import numpy as np
import pandas as pd
import scipy.stats
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-77-001707f5eeab> in <module>
#       6
#       7 f= open("data1.1.txt","w+")
# ----> 8 f.write(open("data1.0.txt").read().replace(',','%'))
#       9 f.close()
#      10 data = pd.read_csv("data1.1.txt", header = None)
#
# ~\Anaconda3\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#      25 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x9d in position 85: character maps to <undefined>

# %%
f= open("ver1.3.txt","w+")
f.write(open("ver1.2.txt").read().replace('%',','))
f.close()
data = pd.read_csv("ver1.3.txt", header = None)

data.rename()
# Out:
#            0               1                    2                   3   \
# 0         NaN        geneName           ST1 to PS1          ST1 to PS2
# 1         1.0           NPTX1    -2.41011720617301    2.21325676978532
# 2         2.0           CELF2   0.0375407110896324  -0.427223381247663
# 3         3.0           ANPEP   -0.481766725437941   0.610212200067631
# 4         4.0            TGM2    0.134661255393507  -0.752667919367839
# ...       ...             ...                  ...                 ...
# 2271  12012.0          GRAMD3    0.293998807962695    -0.5285942730799
# 2272  12270.0         GUCY1A3   -0.239902275207506   0.297676722532002
# 2273  12369.0             LUM    0.551606614256669   -0.26593514225247
# 2274  12664.0           GREM1  -0.0356176732049683    0.42452638697844
# 2275  12743.0  TGIF2-C20ORF24    0.628557585111197  -0.888758976937111
#
#                       4                   5                   6   \
# ...

# %%
data= pd.read_csv("ver2.txt", sep = '\t', lineterminator='\n', nrows = 1000)
data.to_csv("ver2.1.csv")

# %%
data = pd.read_csv()
